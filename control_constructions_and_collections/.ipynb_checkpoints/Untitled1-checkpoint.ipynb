# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

delete_doc = input("Введите номер документа для удаления:")

for i in directories.items():
    print(i)
    for element in i:
        if delete_doc in element:
            element.remove(delete_doc)
       
            
print(directories)

# %%
m – move – команда, которая спросит номер документа и целевую полку и переместит его
с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается
переместить несуществующий документ или переместить документ на несуществующую полку;

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

delete_doc = input("Введите номер документа для перемещения:")

x = 0
for i in directories.values():
    if delete_doc in i:
        x += 1
        i.remove(delete_doc)
    else:
        print("Такого документа не существует")
        break
        
print(directories)

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

doc_number = input("Введите номер документа:")
shelf_number_for_replace = input("Введите номер полки:")

for i in directories.items():
     for element in i:
            if doc_number in element:
                directories[shelf_number_for_replace].append(doc_number)
print(directories)
# Out:
# Введите номер документа:555
# Введите номер полки:1
# {'1': ['2207 876234', '11-2'], '2': ['10006'], '3': []}

# %%
a – add – команда, которая добавит новый документ в каталог и в перечень полок,
спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.
Корректно обработайте ситуацию, когда пользователь будет пытаться 
добавить документ на несуществующую полку.

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]


doc_number = input("Введите номер документа для добавления")
documents_owner = input("Введите имя владельца документа")
document_type = input(str("Введите тип документа"))
shelf_number = input("Введите номер полки хранения")
new_directory = {}
documents.append({'type':document_type,'number':doc_number,'name':documents_owner })
print(documents)

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

check_list = []
for i in directories.values():
    for el in i:
        check_list.append(el)


if doc_number in check_list:
    print("ооо")
else:
    for i in directories.items():
        for el in i:
            if doc_number in el:
                el.remove(doc_number)  
directories[shelf_number].append(doc_number)
directories
print(directories)
# Out:
# Введите номер документа для добавления8888
# Введите имя владельца документаВАся
# Введите тип документапасп
# Введите номер полки хранения1
# [{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'}, {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'}, {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}, {'type': 'пасп', 'number': '8888', 'name': 'ВАся'}]
# {'1': ['2207 876234', '11-2', '8888'], '2': ['10006'], '3': []}

# %%
def a(doc_number,documents_owner,document_type,shelf_number):
    
    documents = [
        {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
        {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
        {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
    ]

    doc_number = input("Введите номер документа для добавления")
    documents_owner = input("Введите имя владельца документа")
    document_type = input(str("Введите тип документа"))
    shelf_number = input("Введите номер полки хранения")
    new_directory = {}
    documents.append({'type':document_type,'number':doc_number,'name':documents_owner })
    print(documents)

    directories = {
        '1': ['2207 876234', '11-2'],
        '2': ['10006'],
        '3': []
    }

    check_list = []
    for i in directories.values():
        for el in i:
            check_list.append(el)


    if doc_number in check_list:
        print("ооо")
    else:
        for i in directories.items():
            for el in i:
                if doc_number in el:
                    el.remove(doc_number)  
    directories[shelf_number].append(doc_number)
    directories
    
    return directories
    print(directories)

# %%
a(doc_number,documents_owner,document_type,shelf_number)

# %%
Capitals = {}
Capitals['1'] = 'Moscow'
Capitals['2'] = 'Kiev'
Capitals['3'] = 'Washington'
Capitals['4'] = 'jkmj'
Capitals['5'] = 'jgjgg'
Capitals['6'] = 'Wfjfjn'
Capitals['7'] = 'Moscow'
Capitals['8'] = 'Kiev'
Capitals['9'] = 'fjfWashfjfjfton'
Capitals['10'] = 'Wafjfjfton'
Capitals['11'] = 'Mfjfw'
Capitals['12'] = 'Kievkjh'
Capitals['13'] = 'fjfjjon'

for i in Capitals.keys():
    print(Capitals[i] + " is the capital of " + i)


new_dict = {}
for i in Capitals:
  new_dict[Capitals[i]] = i
print(new_dict)


m = Capitals.keys()
for i in m:
  # i - это элемент, например Москва
  for j in m:
    # j - это список городов
    if Capitals[i] == Capitals[j] and i != j:
      del(Capitals[j])
      m = Capitals.keys()
      
for i in m:      
  print(Capitals[i] + '/n')

# %%
Capitals = {}
Capitals['1'] = 'Moscow'
Capitals['2'] = 'Kiev'
Capitals['3'] = 'Washington'
Capitals['4'] = 'jkmj'
Capitals['5'] = 'jgjgg'
Capitals['6'] = 'Wfjfjn'
Capitals['7'] = 'Mosklcow'
Capitals['8'] = 'Kffiev'
Capitals['9'] = 'fjfWashfjfjfton'
Capitals['10'] = 'Wafjfjfton'
Capitals['11'] = 'Mfjfw'
Capitals['12'] = 'Kievkjh'
Capitals['13'] = 'fjfjjon'  

Ca = {}
Ca['1'] = 'Mofjfdhjscow'
Ca['2'] = 'Kidjdjev'
Ca['3'] = 'Washijdngton'
Ca['4'] = 'jkmdjj'
Ca['5'] = 'jgjdjgg'
Ca['6'] = 'Wfjfsgjn'
Ca['7'] = 'Moscow'
Ca['8'] = 'Kiev'
Ca['9'] = 'fjfssshWashfjfjfton'
Ca['10'] = 'Waffhhfjfjfton'
Ca['11'] = 'Mfjfhffw'
Ca['12'] = 'Kiedhdgvkjh'
Ca['13'] = 'fjfgdhdhdjjon'
Ca['14'] = 'Moscow'
Ca['15'] = 'Kievkjh'
Ca['16'] = 'fjfjjon' 

new_list = []
for i in Capitals:
  new_list.append(Capitals[i])
print(new_list)

new_list2 = []
for i in Ca:
  new_list2.append(Ca[i])
print(new_list2)

new_list3 = []
for i in new_list:
  if i == j:
      new_list3.append(i)
      break
      

print(new_list3)
